# %% [markdown]
# # Считаем IDFы слов коллекции
#
# Входные данные: коллекция из N текстовых документов.
#
# Надо: посчитать IDFы всех слов, которые содержатся в коллекции.

# %% [markdown]
# Импортируем модули которые нам понадобятся впоследствии:

# %%
import math
from collections import defaultdict
from nltk import tokenize
import numpy as np

# %% [markdown]
# Список документов (названия институтов):

# %%
texts = [
    "Московская государственная академия хореографии",
    "Московский государственный университет им. М.В. Ломоносова",
    "Московский физико-технический институт (национальный исследовательский университет)",
    "Национальный исследовательский университет «МИЭТ»",
    "Национальный исследовательский университет ИТМО",
]
print(texts)
# Out:
# ['Московская государственная академия хореографии', 'Московский государственный университет им. М.В. Ломоносова', 'Московский физико-технический институт (национальный исследовательский университет)', 'Национальный исследовательский университет «МИЭТ»', 'Национальный исследовательский университет ИТМО']

# %% [markdown]
# Определим функцию, которую будем использовать для предобработки текста:

# %%
def preprocess(text):
    # Tokenize
    tokenizer = tokenize.RegexpTokenizer(r'\w\w+')
    tokens = tokenizer.tokenize(text)

    # Normalize
    return [token.lower() for token in tokens]

# %% [markdown]
# Проверим, что она работает:

# %%
print(preprocess(texts[1]))
# Out:
# ['московский', 'государственный', 'университет', 'им', 'ломоносова']

# %% [markdown]
# Видим, что эта функция удаляет пунктуацию и оставляет только слова длиной в 2 и более символов.

# %% [markdown]
# Теперь объявим шаблон для нашего класса-векторизатора, который вам предстоит реализовать:

# %%
class ManualTfidfVectorizer:
    """Replicates sklearn logic.

    Uses IDF definition: IDF(t) = 1 + ln((N + 1) / (DF(t) + 1))
    """
    def __init__(self):
        pass

    def fit(self, texts):
        pass

    def get_idf(self, word):
        return 0

# %% [markdown]
# Вам нужно реализовать функцию _fit()_, в которой вы должны рассчитать и запомнить IDFы всех слова коллекции.
#
# IDF определим по формуле, которая используется классом _TfidfVectorizer_ из библиотеки _scikit-learn_, а именно:
#
# **IDF(t) = 1 + ln((N + 1) / (DF(t) + 1))**
#
# тут:
# - **N** -- полное число документов в коллекции
# - **DF(t)** -- документная частота, т.е. число документов, в которых содержится слово **t**

# %% [markdown]
# Создадим наш векторизатор и "обучим" его на нашей коллекции документов:

# %%
vectorizer = ManualTfidfVectorizer()
vectorizer.fit(texts)

# %% [markdown]
# Распечатаем IDFы отдельных слов:

# %%
print(vectorizer.get_idf("академия"))
print(vectorizer.get_idf("университет"))
# Out:
# 0
# 0

# %% [markdown]
# Проверим, что эти IDFы соответствуют тем, которые выдает библиотека _scikit-learn_:

# %%
idfs = [vectorizer.get_idf("академия"), vectorizer.get_idf("университет")]
np.testing.assert_allclose([2.09861229, 1.18232156], idfs, rtol=1e-03, atol=1e-03)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[52], line 2
#       1 idfs = [vectorizer.get_idf("академия"), vectorizer.get_idf("университет")]
# ----> 2 np.testing.assert_allclose([2.09861229, 1.18232156], idfs, rtol=1e-03, atol=1e-03)
#
#     [... skipping hidden 1 frame]
#
# File /usr/lib/python3.12/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File ~/edu/vk-ir-course-fall-2024/.venvs/seminar-05-text-ranking-p1/lib/python3.12/site-packages/numpy/testing/_private/utils.py:797, in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf, strict)
#     793         err_msg += '\n' + '\n'.join(remarks)
#     794         msg = build_err_msg([ox, oy], err_msg,
#     795                             verbose=verbose, header=header,
#     796                             names=('x', 'y'), precision=precision)
# --> 797         raise AssertionError(msg)
#     798 except ValueError:
#     799     import traceback
#
# AssertionError:
# Not equal to tolerance rtol=0.001, atol=0.001
#
# Mismatched elements: 2 / 2 (100%)
# Max absolute difference: 2.09861229
# Max relative difference: inf
#  x: array([2.098612, 1.182322])
#  y: array([0, 0])
